# %% [markdown]
# <h1> <center> 빅데이터 </center> </h1>
# <h2><center>2020.09.16</center>
# <br>
# <center>서 강 원 </center> </h2>
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
font_path = 'C:/Windows/Fonts/NGULIM.TTF'
fontprop = fm.FontProperties(fname=font_path, size=15)
font_family = fm.FontProperties(fname=font_path).get_name()

plt.rcParams["font.family"] = font_family

# %%
xlsx = pd.ExcelFile('6270000/6270000_대구광역시_07_24_04_P_일반음식점.xlsx')
cafe = pd.read_excel(xlsx,'일반음식점_1')
cafe
# Out:
#           번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  \
# 0          1  일반음식점  07_24_04_P   3410000  3410000-101-2002-00042  20020321
# 1          2  일반음식점  07_24_04_P   3410000  3410000-101-2002-00043  20020322
# 2          3  일반음식점  07_24_04_P   3410000  3410000-101-2002-00046  20020322
# 3          4  일반음식점  07_24_04_P   3410000  3410000-101-2002-00067  20020325
# 4          5  일반음식점  07_24_04_P   3410000  3410000-101-2002-00041  20020325
# ...      ...    ...         ...       ...                     ...       ...
# 79202  79203  일반음식점  07_24_04_P   3480000  3480000-101-2014-00071  20140502
# 79203  79204  일반음식점  07_24_04_P   3480000  3480000-101-2014-00072  20140502
# 79204  79205  일반음식점  07_24_04_P   3480000  3480000-101-2014-00073  20140502
# 79205  79206  일반음식점  07_24_04_P   3480000  3480000-101-2003-00053  20030530
# 79206  79207  일반음식점  07_24_04_P   3480000  3480000-101-2002-00012  20020118
#
# ...

# %%
open_cafe = cafe[cafe["상세영업상태명"] == '영업']
open_cafe
# Out:
#           번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  \
# 4579    4580  일반음식점  07_24_04_P   3410000  3410000-101-2020-00060  20200324
# 4580    4581  일반음식점  07_24_04_P   3410000  3410000-101-2020-00061  20200324
# 4581    4582  일반음식점  07_24_04_P   3410000  3410000-101-2020-00045  20200226
# 4582    4583  일반음식점  07_24_04_P   3410000  3410000-101-2020-00046  20200226
# 4583    4584  일반음식점  07_24_04_P   3410000  3410000-101-2020-00039  20200214
# ...      ...    ...         ...       ...                     ...       ...
# 79202  79203  일반음식점  07_24_04_P   3480000  3480000-101-2014-00071  20140502
# 79203  79204  일반음식점  07_24_04_P   3480000  3480000-101-2014-00072  20140502
# 79204  79205  일반음식점  07_24_04_P   3480000  3480000-101-2014-00073  20140502
# 79205  79206  일반음식점  07_24_04_P   3480000  3480000-101-2003-00053  20030530
# 79206  79207  일반음식점  07_24_04_P   3480000  3480000-101-2002-00012  20020118
#
# ...

# %%
open_cafe = open_cafe.dropna(subset=['업태구분명'])
open_chicken_cafe = open_cafe.loc[open_cafe['업태구분명'].str.contains('통닭')]
open_chicken_cafe
# Out:
#           번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호     인허가일자  \
# 4589    4590  일반음식점  07_24_04_P   3410000  3410000-101-2020-00012  20200114
# 4604    4605  일반음식점  07_24_04_P   3410000  3410000-101-2020-00006  20200107
# 4627    4628  일반음식점  07_24_04_P   3410000  3410000-101-2020-00059  20200320
# 4684    4685  일반음식점  07_24_04_P   3410000  3410000-101-2002-00045  20020329
# 4699    4700  일반음식점  07_24_04_P   3410000  3410000-101-2020-00041  20200218
# ...      ...    ...         ...       ...                     ...       ...
# 79184  79185  일반음식점  07_24_04_P   3480000  3480000-101-1997-00129  19970816
# 79186  79187  일반음식점  07_24_04_P   3480000  3480000-101-1997-00141  19971002
# 79189  79190  일반음식점  07_24_04_P   3480000  3480000-101-2008-00061  20080624
# 79200  79201  일반음식점  07_24_04_P   3480000  3480000-101-2014-00049  20140319
# 79204  79205  일반음식점  07_24_04_P   3480000  3480000-101-2014-00073  20140502
#
# ...

# %%
open_chicken_cafe = open_chicken_cafe.reset_index()
open_chicken_cafe
# Out:
#       index     번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호  \
# 0      4589   4590  일반음식점  07_24_04_P   3410000  3410000-101-2020-00012
# 1      4604   4605  일반음식점  07_24_04_P   3410000  3410000-101-2020-00006
# 2      4627   4628  일반음식점  07_24_04_P   3410000  3410000-101-2020-00059
# 3      4684   4685  일반음식점  07_24_04_P   3410000  3410000-101-2002-00045
# 4      4699   4700  일반음식점  07_24_04_P   3410000  3410000-101-2020-00041
# ...     ...    ...    ...         ...       ...                     ...
# 3364  79184  79185  일반음식점  07_24_04_P   3480000  3480000-101-1997-00129
# 3365  79186  79187  일반음식점  07_24_04_P   3480000  3480000-101-1997-00141
# 3366  79189  79190  일반음식점  07_24_04_P   3480000  3480000-101-2008-00061
# 3367  79200  79201  일반음식점  07_24_04_P   3480000  3480000-101-2014-00049
# 3368  79204  79205  일반음식점  07_24_04_P   3480000  3480000-101-2014-00073
#
#          인허가일자  인허가취소일자  영업상태구분코드  영업상태명  ...  공장판매직종업원수 공장생산직종업원수  건물소유구분명  \
# ...

# %%
open_chicken_cafe = open_chicken_cafe.dropna(subset=['소재지전체주소'])

# %%
a = []
for i in open_chicken_cafe.index:
   a.append(open_chicken_cafe['소재지전체주소'][i].split(' ')[2])
open_chicken_cafe['동'] = a

# %%
open_chicken_cafe
# Out:
#       index     번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호  \
# 0      4589   4590  일반음식점  07_24_04_P   3410000  3410000-101-2020-00012
# 1      4604   4605  일반음식점  07_24_04_P   3410000  3410000-101-2020-00006
# 2      4627   4628  일반음식점  07_24_04_P   3410000  3410000-101-2020-00059
# 3      4684   4685  일반음식점  07_24_04_P   3410000  3410000-101-2002-00045
# 4      4699   4700  일반음식점  07_24_04_P   3410000  3410000-101-2020-00041
# ...     ...    ...    ...         ...       ...                     ...
# 3364  79184  79185  일반음식점  07_24_04_P   3480000  3480000-101-1997-00129
# 3365  79186  79187  일반음식점  07_24_04_P   3480000  3480000-101-1997-00141
# 3366  79189  79190  일반음식점  07_24_04_P   3480000  3480000-101-2008-00061
# 3367  79200  79201  일반음식점  07_24_04_P   3480000  3480000-101-2014-00049
# 3368  79204  79205  일반음식점  07_24_04_P   3480000  3480000-101-2014-00073
#
#          인허가일자  인허가취소일자  영업상태구분코드  영업상태명  ...  공장생산직종업원수 건물소유구분명  보증액  월세액  \
# ...

# %%
open_chicken_cafe_vc = open_chicken_cafe['동'].value_counts()
open_chicken_cafe_vc = pd.DataFrame(open_chicken_cafe_vc)
open_chicken_cafe_vc
# Out:
#          동
# 대명동    149
# 다사읍    118
# 상인동    111
# 태전동     92
# 평리동     91
# ...    ...
# 화전동      1
# 월암동      1
# 동성로2가    1
# 중대동      1
# 덕산동      1
#
# [145 rows x 1 columns]

# %%
open_chicken_cafe_vc.iloc[0].name
# Out:
# '대명동'

# %%
a = []
for i in open_chicken_cafe.index:
   a.append(open_chicken_cafe['소재지전체주소'][i].split(' ')[1])
open_chicken_cafe['구'] = a

# %%
open_chicken_cafe
# Out:
#       index     번호 개방서비스명     개방서비스ID  개방자치단체코드                    관리번호  \
# 0      4589   4590  일반음식점  07_24_04_P   3410000  3410000-101-2020-00012
# 1      4604   4605  일반음식점  07_24_04_P   3410000  3410000-101-2020-00006
# 2      4627   4628  일반음식점  07_24_04_P   3410000  3410000-101-2020-00059
# 3      4684   4685  일반음식점  07_24_04_P   3410000  3410000-101-2002-00045
# 4      4699   4700  일반음식점  07_24_04_P   3410000  3410000-101-2020-00041
# ...     ...    ...    ...         ...       ...                     ...
# 3364  79184  79185  일반음식점  07_24_04_P   3480000  3480000-101-1997-00129
# 3365  79186  79187  일반음식점  07_24_04_P   3480000  3480000-101-1997-00141
# 3366  79189  79190  일반음식점  07_24_04_P   3480000  3480000-101-2008-00061
# 3367  79200  79201  일반음식점  07_24_04_P   3480000  3480000-101-2014-00049
# 3368  79204  79205  일반음식점  07_24_04_P   3480000  3480000-101-2014-00073
#
#          인허가일자  인허가취소일자  영업상태구분코드  영업상태명  ...  건물소유구분명 보증액  월세액  다중이용업소여부  \
# ...

# %%
open_chicken_cafe_vc2 = open_chicken_cafe['구'].value_counts()
open_chicken_cafe_vc2 = pd.DataFrame(open_chicken_cafe_vc2)
open_chicken_cafe_vc2
# Out:
#        구
# 달서구  841
# 북구   618
# 수성구  453
# 동구   422
# 달성군  394
# 서구   249
# 남구   207
# 중구   183

# %%
open_chicken_cafe_vc2.plot(kind='bar') 
plt.show()

# %%
df = cafe[['상세영업상태명','소재지전체주소','사업장명','업태구분명']]

# %%
df
# Out:
#       상세영업상태명                           소재지전체주소         사업장명  업태구분명
# 0          폐업            대구광역시 중구 계산동2가 0171번지           옛날집     한식
# 1          폐업  대구광역시 중구 동성로3가 0016-0010번지 외7필지        명계안동찜닭     한식
# 2          폐업       대구광역시 중구 삼덕동1가 0022-0012번지        달구벌찜한식     한식
# 3          폐업       대구광역시 중구 동인동1가 0089-0002번지          맥향식당     한식
# 4          폐업         대구광역시 중구 문화동 0007-0007번지           차하늘     한식
# ...       ...                               ...          ...    ...
# 79202      영업           대구광역시 달성군 다사읍 서재리 91번지       칭구짬뽕서재점    중국식
# 79203      영업        대구광역시 달성군 다사읍 죽곡리 152-1번지        만나코다리찜     한식
# 79204      영업        대구광역시 달성군 다사읍 죽곡리 857-6번지   처갓집양념치킨 죽곡점  호프/통닭
# 79205      영업         대구광역시 달성군 가창면 옥분리 69-2번지          묵항아리     기타
# 79206      영업          대구광역시 달성군 하빈면 현내리 932번지          부영식당     한식
#
# [79207 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79207 entries, 0 to 79206
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   상세영업상태명  79207 non-null  object
#  1   소재지전체주소  79181 non-null  object
#  2   사업장명     79207 non-null  object
#  3   업태구분명    79204 non-null  object
# dtypes: object(4)
# memory usage: 2.4+ MB

# %%
#결측치 삭제
df = df.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79178 entries, 0 to 79206
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   상세영업상태명  79178 non-null  object
#  1   소재지전체주소  79178 non-null  object
#  2   사업장명     79178 non-null  object
#  3   업태구분명    79178 non-null  object
# dtypes: object(4)
# memory usage: 3.0+ MB

# %%
# 앞 공백제거
df['소재지전체주소'] = df['소재지전체주소'].str.lstrip()

# %%
df
# Out:
#       상세영업상태명                           소재지전체주소         사업장명  업태구분명
# 0          폐업            대구광역시 중구 계산동2가 0171번지           옛날집     한식
# 1          폐업  대구광역시 중구 동성로3가 0016-0010번지 외7필지        명계안동찜닭     한식
# 2          폐업       대구광역시 중구 삼덕동1가 0022-0012번지        달구벌찜한식     한식
# 3          폐업       대구광역시 중구 동인동1가 0089-0002번지          맥향식당     한식
# 4          폐업         대구광역시 중구 문화동 0007-0007번지           차하늘     한식
# ...       ...                               ...          ...    ...
# 79202      영업           대구광역시 달성군 다사읍 서재리 91번지       칭구짬뽕서재점    중국식
# 79203      영업        대구광역시 달성군 다사읍 죽곡리 152-1번지        만나코다리찜     한식
# 79204      영업        대구광역시 달성군 다사읍 죽곡리 857-6번지   처갓집양념치킨 죽곡점  호프/통닭
# 79205      영업         대구광역시 달성군 가창면 옥분리 69-2번지          묵항아리     기타
# 79206      영업          대구광역시 달성군 하빈면 현내리 932번지          부영식당     한식
#
# [79178 rows x 4 columns]

# %%
df = df[df['상세영업상태명'] == '영업']
df
# Out:
#       상세영업상태명                      소재지전체주소             사업장명       업태구분명
# 4579       영업  대구광역시 중구 삼덕동3가 0277-0006번지             에이글라스         경양식
# 4580       영업  대구광역시 중구 삼덕동3가 0177-0001번지                 담          일식
# 4581       영업  대구광역시 중구 동인동3가 0271-0001번지              울릉식당          한식
# 4582       영업         대구광역시 중구 동산동 0802번지              대영식당          한식
# 4583       영업         대구광역시 중구 공평동 0093번지   뉴스쿨(NEW SCHOOL)  정종/대포집/소주방
# ...       ...                          ...              ...         ...
# 79202      영업      대구광역시 달성군 다사읍 서재리 91번지           칭구짬뽕서재점         중국식
# 79203      영업   대구광역시 달성군 다사읍 죽곡리 152-1번지            만나코다리찜          한식
# 79204      영업   대구광역시 달성군 다사읍 죽곡리 857-6번지       처갓집양념치킨 죽곡점       호프/통닭
# 79205      영업    대구광역시 달성군 가창면 옥분리 69-2번지              묵항아리          기타
# 79206      영업     대구광역시 달성군 하빈면 현내리 932번지              부영식당          한식
#
# [30509 rows x 4 columns]

# %%
df[['시도','구','동','나머지']] = df['소재지전체주소'].str.split(' ', n=3, expand=True)# 여러개 : expand=True 한개 : False
df
# Out:
#       상세영업상태명                      소재지전체주소             사업장명       업태구분명  \
# 4579       영업  대구광역시 중구 삼덕동3가 0277-0006번지             에이글라스         경양식
# 4580       영업  대구광역시 중구 삼덕동3가 0177-0001번지                 담          일식
# 4581       영업  대구광역시 중구 동인동3가 0271-0001번지              울릉식당          한식
# 4582       영업         대구광역시 중구 동산동 0802번지              대영식당          한식
# 4583       영업         대구광역시 중구 공평동 0093번지   뉴스쿨(NEW SCHOOL)  정종/대포집/소주방
# ...       ...                          ...              ...         ...
# 79202      영업      대구광역시 달성군 다사읍 서재리 91번지           칭구짬뽕서재점         중국식
# 79203      영업   대구광역시 달성군 다사읍 죽곡리 152-1번지            만나코다리찜          한식
# 79204      영업   대구광역시 달성군 다사읍 죽곡리 857-6번지       처갓집양념치킨 죽곡점       호프/통닭
# 79205      영업    대구광역시 달성군 가창면 옥분리 69-2번지              묵항아리          기타
# 79206      영업     대구광역시 달성군 하빈면 현내리 932번지              부영식당          한식
#
#           시도    구      동           나머지
# 4579   대구광역시   중구  삼덕동3가  0277-0006번지
# ...

# %%
df = df[['상세영업상태명','사업장명','업태구분명','구','동']]

# %%
df
# Out:
#       상세영업상태명             사업장명       업태구분명    구      동
# 4579       영업            에이글라스         경양식   중구  삼덕동3가
# 4580       영업                담          일식   중구  삼덕동3가
# 4581       영업             울릉식당          한식   중구  동인동3가
# 4582       영업             대영식당          한식   중구    동산동
# 4583       영업  뉴스쿨(NEW SCHOOL)  정종/대포집/소주방   중구    공평동
# ...       ...              ...         ...  ...    ...
# 79202      영업          칭구짬뽕서재점         중국식  달성군    다사읍
# 79203      영업           만나코다리찜          한식  달성군    다사읍
# 79204      영업      처갓집양념치킨 죽곡점       호프/통닭  달성군    다사읍
# 79205      영업             묵항아리          기타  달성군    가창면
# 79206      영업             부영식당          한식  달성군    하빈면
#
# [30509 rows x 5 columns]

# %%
df2 = df[df['업태구분명'].isin(['호프/통닭','통닭(치킨'])]
df2
# Out:
#       상세영업상태명            사업장명  업태구분명    구      동
# 4589       영업          반월당닭강정  호프/통닭   중구    공평동
# 4604       영업        상상치킨 남산점  호프/통닭   중구    남산동
# 4627       영업              또야  호프/통닭   중구    남산동
# 4684       영업  구루카페(GuruCafe)  호프/통닭   중구  삼덕동1가
# 4699       영업    반월당닭강정 염매시장점  호프/통닭   중구    남성로
# ...       ...             ...    ...  ...    ...
# 79126      영업        범프리카인생치킨  호프/통닭  달성군    유가읍
# 79129      영업            도시포차  호프/통닭  달성군    현풍읍
# 79133      영업        60계대구옥포점  호프/통닭  달성군    옥포읍
# 79184      영업     허갈 닭강정 & 치킨  호프/통닭  달성군    화원읍
# 79204      영업     처갓집양념치킨 죽곡점  호프/통닭  달성군    다사읍
#
# [2081 rows x 5 columns]

# %%
all_names = pd.Series(df.업태구분명.unique())
chicken_like = all_names[all_names.str.contains('통닭')]
chicken_like
# Out:
# 5      호프/통닭
# 12    통닭(치킨)
# dtype: object

# %%
df3 = df[df['업태구분명'].isin(chicken_like)]
df3
# Out:
#       상세영업상태명            사업장명   업태구분명    구      동
# 4589       영업          반월당닭강정   호프/통닭   중구    공평동
# 4604       영업        상상치킨 남산점   호프/통닭   중구    남산동
# 4627       영업              또야   호프/통닭   중구    남산동
# 4684       영업  구루카페(GuruCafe)   호프/통닭   중구  삼덕동1가
# 4699       영업    반월당닭강정 염매시장점   호프/통닭   중구    남성로
# ...       ...             ...     ...  ...    ...
# 79184      영업     허갈 닭강정 & 치킨   호프/통닭  달성군    화원읍
# 79186      영업    원조을지로노가리,골뱅이  통닭(치킨)  달성군    논공읍
# 79189      영업        종국이두마리치킨  통닭(치킨)  달성군    다사읍
# 79200      영업         베트남 쌀국수  통닭(치킨)  달성군    현풍읍
# 79204      영업     처갓집양념치킨 죽곡점   호프/통닭  달성군    다사읍
#
# [3367 rows x 5 columns]

# %%
df = df3

# %%
df.dtypes
# Out:
# 상세영업상태명    object
# 사업장명       object
# 업태구분명      object
# 구          object
# 동          object
# dtype: object

# %%
df['count']=1
df
# Out:
#       상세영업상태명            사업장명   업태구분명    구      동  count
# 4589       영업          반월당닭강정   호프/통닭   중구    공평동      1
# 4604       영업        상상치킨 남산점   호프/통닭   중구    남산동      1
# 4627       영업              또야   호프/통닭   중구    남산동      1
# 4684       영업  구루카페(GuruCafe)   호프/통닭   중구  삼덕동1가      1
# 4699       영업    반월당닭강정 염매시장점   호프/통닭   중구    남성로      1
# ...       ...             ...     ...  ...    ...    ...
# 79184      영업     허갈 닭강정 & 치킨   호프/통닭  달성군    화원읍      1
# 79186      영업    원조을지로노가리,골뱅이  통닭(치킨)  달성군    논공읍      1
# 79189      영업        종국이두마리치킨  통닭(치킨)  달성군    다사읍      1
# 79200      영업         베트남 쌀국수  통닭(치킨)  달성군    현풍읍      1
# 79204      영업     처갓집양념치킨 죽곡점   호프/통닭  달성군    다사읍      1
#
# [3367 rows x 6 columns]

# %%
chicken = df.groupby('동').sum()
chicken = chicken.sort_values(by='count',ascending=False)
chicken
# Out:
#      count
# 동
# 대명동    149
# 다사읍    118
# 상인동    111
# 태전동     92
# 평리동     91
# ..     ...
# 월암동      1
# 대림동      1
# 이현동      1
# 전동       1
# 가창면      1
#
# [145 rows x 1 columns]

# %%
ids, cols = np.where(chicken == chicken.values.max())
chicken.iloc[ids]
# Out:
#      count
# 동
# 대명동    149

# %%
top10 = chicken.sort_values(by='count' ,ascending=False)[:10]
top10
# Out:
#      count
# 동
# 대명동    149
# 다사읍    118
# 상인동    111
# 태전동     92
# 평리동     91
# 신암동     88
# 비산동     82
# 산격동     81
# 송현동     76
# 두류동     72

# %%
top10_values = list(np.ravel(top10.values))
x = np.arange(len(top10_values))  # the label locations
width = 0.6  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6)) #fig, ax = plt.subplots(TOTAL_X,TOTAL_Y,figsize=(8, 5))
plt.grid(b=True, which='both', axis='both')
rects1 = ax.bar(top10.index, top10_values, width, align='center', alpha=0.5, label='치킨집 수')
rects1[top10_values.index(max(top10_values))].set_color('g')

ax.set_title('동네별 치킨집의 수 Top10')
ax.set_xticks(x)
ax.set_xticklabels(top10.index)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
fig.tight_layout()

plt.show()

# %%
chicken_gu = df.groupby('구').sum()
chicken_gu
# Out:
#      count
# 구
# 남구     207
# 달서구    841
# 달성군    394
# 동구     422
# 북구     618
# 서구     249
# 수성구    453
# 중구     183

# %%
print(chicken_gu.values)
print(chicken_gu.index)
# Out:
# [[207]
#  [841]
#  [394]
#  [422]
#  [618]
#  [249]
#  [453]
#  [183]]
# Index(['남구', '달서구', '달성군', '동구', '북구', '서구', '수성구', '중구'], dtype='object', name='구')

# %%
num_chickens = list(np.ravel(chicken_gu.values))
num_chickens
# Out:
# [207, 841, 394, 422, 618, 249, 453, 183]

# %%
labels =np.ravel(chicken_gu.values)
x = np.arange(len(labels))  # the label locations
width = 0.6  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 5)) #fig, ax = plt.subplots(TOTAL_X,TOTAL_Y,figsize=(8, 5))

plt.grid(b=True, which='both', axis='both')
rects1 = ax.bar(chicken_gu.index, np.ravel(labels), width, align='center', alpha=0.5, label='치킨집 수')
rects1[num_chickens.index(max(num_chickens))].set_color('g')


ax.set_title('구별 치킨집 수')
ax.set_xticks(x)
ax.set_xticklabels(chicken_gu.index)
ax.legend()

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
fig.tight_layout()

plt.show()
